# %%
import bids2gallery
import glob

# %%
import importlib
importlib.reload(bids2gallery)
# Out:
# <module 'bids2gallery' from '/media/raid/orco/data/ICH/code/bids2gallery/bids2gallery.py'>

# %%
subs = glob.glob('/home/orco/data/ICH/sub-*/ses-*/anat/sub-*_ses-*_space-native_desc-CT.nii.gz')

# %%
len(subs)
# Out:
# 2029

# %%
sbs = subs[:2]

# %%
bids2gallery.subs2html(sbs)
# Out:
# /home/orco/anaconda3/envs/mrs/lib/python3.9/site-packages/scipy/ndimage/measurements.py:1406: RuntimeWarning: invalid value encountered in true_divide
#   results = [sum(input * grids[dir].astype(float), labels, index) / normalizer
# {'sid': 'sub-H197', 'ses': 'ses-02', 'img': './imgs/sub-H197_ses-02.png'}
# {'sid': 'sub-H197', 'ses': 'ses-01', 'img': './imgs/sub-H197_ses-01.png'}
# 'gallery.html'
